# %% [markdown]
# # Force Reload of `water_quality_analysis`
#
# This notebook clears the module cache, imports the station map helper, and renders the map from `station.csv`.

# %%
import importlib
import sys

if 'water_quality_analysis' in sys.modules:
    del sys.modules['water_quality_analysis']

print('Module cache cleared. Ready to run cells.')

# %% [markdown]
# # Import `build_station_map_folium`
#
# Import the helper that builds the station map from `station.csv`.

# %%
from water_quality_sites import build_station_map_folium
# Out:
# Running cells with 'Python 3.11.2' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Display Water Quality Stations Map
#
# Call the helper with `station.csv` to render the folium map inline.

# %%
# Returns a folium.Map object; Jupyter will render it inline
build_station_map_folium('station.csv')
# Out:
# Running cells with 'Python 3.11.2' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
